# %%
# importing libraries

import pandas as pd
import numpy as np
import os

# %%
# folder path into a string 
path = r'C:\\Users\\Jalon\\Desktop\\python_projects\\4.3_orders_products'

# %%
#importing the "orders.csv" data set using oslibrary and omitting
#the os library.

df = pd.read_csv(os.path.join(path,'orders.csv'), index_col = False)

# %%
df_ords = df

# %%
#droping column eval_set from df_ords and assigning the new df to df_ordss_2
df_ords_2 = df_ords.drop(columns = ['eval_set'])

# %%
# renaming the column order_dow
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, 
               
               inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
#changing order_id type a more suitable type
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# reading the departments data set and assigning it to df_dep
df_dep = pd.read_csv('departments.csv', index_col = False)

# %%
# Transposing df_dep
df_dep_t =df_dep.T

# %%
#reseting the index for transposed df_dep
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#assigning the first row to new_header
new_header = df_dep_t.iloc[0]

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
#assigning new_header as columns for df_dep_t_new
df_dep_t_new.columns = new_header

# %%
df_dep_t_new.columns
# Out:
# Index(['department'], dtype='object', name='department_id')

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#assigngin df_dep_t_new as dictionary to data_dic
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# # 02 Exercice 4.4 Data Wrangling Subsetting

# %%
#QN1 was already done in the section above.

# %%
df_ords.head(5)
# Out:
#   order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0  2539329        1    prior             1                   2
# 1  2398795        1    prior             2                   3
# 2   473747        1    prior             3                   3
# 3  2254736        1    prior             4                   4
# 4   431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords["user_id"].dtype
# Out:
# dtype('int64')

# %%
#QN2: changing the type of user_id column to a suitable format
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
#describing df_ords
df_ords.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.715486e+01        2.776219e+00       1.345202e+01
# std    1.773316e+01        2.046829e+00       4.226088e+00
# min    1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.100000e+01        3.000000e+00       1.300000e+01
# 75%    2.300000e+01        5.000000e+00       1.600000e+01
# max    1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
df_ords
# Out:
#         order_id user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329       1    prior             1                   2
# 1        2398795       1    prior             2                   3
# 2         473747       1    prior             3                   3
# 3        2254736       1    prior             4                   4
# 4         431534       1    prior             5                   4
# ...          ...     ...      ...           ...                 ...
# 3421078  2266710  206209    prior            10                   5
# 3421079  1854736  206209    prior            11                   4
# 3421080   626363  206209    prior            12                   1
# 3421081  2977660  206209    prior            13                   1
# 3421082   272231  206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
# QN3: changing column 'orders_day_of_week' to 'order_day_of_week'
df_ords_qn3 = df_ords.rename(columns = {'orders_day_of_week' : 'order_day_of_week'} )

# %%
df_ords_qn3
# Out:
#         order_id user_id eval_set  order_number  order_day_of_week  \
# 0        2539329       1    prior             1                  2
# 1        2398795       1    prior             2                  3
# 2         473747       1    prior             3                  3
# 3        2254736       1    prior             4                  4
# 4         431534       1    prior             5                  4
# ...          ...     ...      ...           ...                ...
# 3421078  2266710  206209    prior            10                  5
# 3421079  1854736  206209    prior            11                  4
# 3421080   626363  206209    prior            12                  1
# 3421081  2977660  206209    prior            13                  1
# 3421082   272231  206209    train            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# ...

# %%
df_ords["order_hour_of_day"].value_counts()
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
# QN4 busiest hour is 10 with 288 418 orders

# %%
df_ords
# Out:
#         order_id user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329       1    prior             1                   2
# 1        2398795       1    prior             2                   3
# 2         473747       1    prior             3                   3
# 3        2254736       1    prior             4                   4
# 4         431534       1    prior             5                   4
# ...          ...     ...      ...           ...                 ...
# 3421078  2266710  206209    prior            10                   5
# 3421079  1854736  206209    prior            11                   4
# 3421080   626363  206209    prior            12                   1
# 3421081  2977660  206209    prior            13                   1
# 3421082   272231  206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
data_dict.get('4')
#the department_id 4 meands produce
# Out:
# {'department': 'produce'}

# %%
# opening the data set products and assigning it to df_prods
df_prods = pd.read_csv(os.path.join(path,'products.csv'), index_col = False)

# %%
# QN6 creating a subset containing only the information about breakfast department
df_prods_breakfast = df_prods[df_prods["department_id"]==14]

# %%
# QN7 all observations from the entire 
# dataframe that include items from the
# departments: alcohol, deli, beverages, and meat/seafood 

df_prods_dinner_parties = df_prods[(df_prods["department_id"]==5) | (df_prods["department_id"]==20) |
         
         (df_prods["department_id"]==7) | (df_prods["department_id"]==12)]

# %%
# shape of df_prods_dinner_parties df : 
#7650 rows
df_prods_dinner_parties.shape
# Out:
# (7650, 5)

# %%
#extracting all the information about oder_id 1
df_ords[df_ords["user_id"]=="1"]
# Out:
#    order_id user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329       1    prior             1                   2
# 1   2398795       1    prior             2                   3
# 2    473747       1    prior             3                   3
# 3   2254736       1    prior             4                   4
# 4    431534       1    prior             5                   4
# 5   3367565       1    prior             6                   2
# 6    550135       1    prior             7                   1
# 7   3108588       1    prior             8                   1
# 8   2295261       1    prior             9                   1
# 9   2550362       1    prior            10                   4
# 10  1187899       1    train            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %%
# details about the user_id 1
df_ords[df_ords["user_id"]=="1"].describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# exporting df_ords 
# in my Prepared Data folder as 'orders_wrangled.csv'
df_ords.to_csv(os.path.join(path, 'orders_wrangled.csv'))

# %%
#QN 13 exporting df_dep_t_new 
#to my Data folder as departments_wrangled.csv
df_dep_t_new.to_csv(os.path.join(path, 'departments_wrangled.csv'))

# %% [markdown]
# # 4.5: Data Consistency Checks
#
# ## 4.5.1 consistency checks covered in the Exercise

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  object
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.9+ MB

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 182.7+ MB

# %%
for col in df_prods.columns.tolist():
    weird = (df_prods[[col]].applymap(type) != df_prods[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_prods[weird]) > 0:
        print (col)
# Out:
# product_name

# %%
df_prods["product_name"]
# Out:
# 0                               Chocolate Sandwich Cookies
# 1                                         All-Seasons Salt
# 2                     Robust Golden Unsweetened Oolong Tea
# 3        Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4                                Green Chile Anytime Sauce
#                                ...
# 49688            Vodka, Triple Distilled, Twist of Vanilla
# 49689                   En Croute Roast Hazelnut Cranberry
# 49690                                     Artisan Baguette
# 49691           Smartblend Healthy Metabolism Dry Cat Food
# 49692                               Fresh Foaming Cleanser
# Name: product_name, Length: 49693, dtype: object

# %%
for col in df_ords.columns.tolist():
    weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_ords[weird]) > 0:
        print (col)

# %%
df_ords
# Out:
#         order_id user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329       1    prior             1                   2
# 1        2398795       1    prior             2                   3
# 2         473747       1    prior             3                   3
# 3        2254736       1    prior             4                   4
# 4         431534       1    prior             5                   4
# ...          ...     ...      ...           ...                 ...
# 3421078  2266710  206209    prior            10                   5
# 3421079  1854736  206209    prior            11                   4
# 3421080   626363  206209    prior            12                   1
# 3421081  2977660  206209    prior            13                   1
# 3421082   272231  206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_ords
# Out:
#         order_id user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329       1    prior             1                   2
# 1        2398795       1    prior             2                   3
# 2         473747       1    prior             3                   3
# 3        2254736       1    prior             4                   4
# 4         431534       1    prior             5                   4
# ...          ...     ...      ...           ...                 ...
# 3421078  2266710  206209    prior            10                   5
# 3421079  1854736  206209    prior            11                   4
# 3421080   626363  206209    prior            12                   1
# 3421081  2977660  206209    prior            13                   1
# 3421082   272231  206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
df_ords_null =df_ords[df_ords["days_since_prior_order"].isnull()]

# %%
df_ords_null["order_number"].value_counts()
# Out:
# 1    206209
# Name: order_number, dtype: int64

# %%
df_ords.duplicated().sum()
# Out:
# 0

# %%
df_ords["order_id"].duplicated().sum()
# Out:
# 0

# %%
df_ords[['user_id', 'eval_set', 'order_number', 'orders_day_of_week','order_hour_of_day', 'days_since_prior_order']].duplicated().sum()
# Out:
# 0
